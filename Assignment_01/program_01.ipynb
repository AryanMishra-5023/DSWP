# %% [markdown]
# # Check number is odd or even

# %%
def check(x):
    if(a % 2 == 0):
        print("Number is even")
    else:
        print("Number is odd")
    return;
a = int(input("Enter a number: "))
check(a)
# Out:
# Enter a number:  3435
# Number is odd
