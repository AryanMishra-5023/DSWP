# %% [markdown]
# # Boolean

# %%
print(True,False)
# Out:
# True False

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
mystr = "Aryan2005"
print(mystr.isalnum())
print(mystr.isalpha())
print(mystr.isdigit())
print(mystr.istitle())
print(mystr.isupper())
print(mystr.islower())
# Out:
# True
# False
# False
# True
# False
# False

# %% [markdown]
# # Logical operators

# %%
True and True
# Out:
# True

# %%
False and False
# Out:
# False

# %%
True or True
# Out:
# True

# %%
False or False
# Out:
# False

# %%
Str = 'Aryan'
mystr = '2005'
Str.isalnum() or mystr.isnum()
# Out:
# True
